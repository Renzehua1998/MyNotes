# %%
import igraph as ig
import numpy as np
import pandas as pd
from IPython.core.display import display, SVG
import matplotlib.pyplot as plt
import umap
from scipy.special import comb as choose
import scipy.stats as ss
from itertools import groupby

# %% [markdown]
# ## Erdos-Renyi (ER) Models
#
# random models for graphs

# %%
## The G(n,m) model
n = 50
m = 100
g = ig.Graph.Erdos_Renyi(n=n, m=m, directed=False, loops=False)
g.vs['color'] = 'blue'
g.vs['size'] = 10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
## The G(n,p) model
p = m/choose(n,2) ## as in previous model
g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
g.vs['color'] = 'blue'
g.vs['size'] = 10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
print('number of edges:',g.ecount(),' expected:',np.around(choose(n,2)*p,2))
print('avg degree:',np.mean(g.degree()),' expected:',np.around(p*(n-1),2))
# Out:
# number of edges: 89  expected: 100.0
# avg degree: 3.56  expected: 4.0

# %% [markdown]
# ## Degree distribution

# %%
## larger graph - looking at the degree distribution
n = 1000
p = .01 
g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
m = g.ecount()
print('number of edges:',g.ecount(),' expected:',np.around(choose(n,2)*p,2))
print('avg degree:',np.mean(g.degree()),' expected:',np.around(p*(n-1),2))
# Out:
# number of edges: 5154  expected: 4995.0
# avg degree: 10.308  expected: 9.99

# %%
print(g.degree_distribution())
# Out:
# N = 1000, mean +- sd: 10.3080 +- 3.2183
# Each * represents 2 items
# [ 2,  3): ** (4)
# [ 3,  4): * (2)
# [ 4,  5): ********* (18)
# [ 5,  6): ***************** (34)
# [ 6,  7): ********************** (45)
# [ 7,  8): ************************************* (75)
# [ 8,  9): *********************************************************** (119)
# [ 9, 10): ************************************************************** (124)
# [10, 11): ******************************************************************** (137)
# [11, 12): ****************************************************************** (133)
# [12, 13): **************************************** (81)
# [13, 14): ********************************* (66)
# [14, 15): ************************** (52)
# [15, 16): ************************ (48)
# [16, 17): ********* (18)
# [17, 18): *********** (23)
# [18, 19): ***** (10)
# [19, 20): *** (6)
# [20, 21): * (2)
# [21, 22): * (2)
# [22, 23):  (0)
# [23, 24):  (1)

# %%
## histogram
deg = np.sort(g.degree())
freq = [len(list(group))/len(deg) for key, group in groupby(deg)]
deg = np.unique(deg)
plt.bar(deg,freq)

## compare with Poisson distribution
lam = p*(n-1)
rv = ss.poisson(lam)
x = np.arange(0,26,1)
plt.plot(x, rv.pmf(x),c='r');

# %% [markdown]
# ## Adjacency matrix

# %%
g = ig.Graph.Erdos_Renyi(n=50,m=500)
adj = g.get_adjacency()
A = adj.data
plt.imshow(A, origin='lower' );

# %% [markdown]
# ## Minimum spanning tree, diameter

# %%
g = ig.Graph.Erdos_Renyi(n=50, m=100)
g.vs['size']=10
g.vs['color']='lightblue'
e = g.spanning_tree(return_tree=False)
g.es['color'] = 'grey'
g.es['width'] = 1
for x in e:
    g.es[x]['color'] = 'red'
    g.es[x]['width'] = 2
ig.plot(g, layout="fr", vertex_label=None, bbox=(0,0,350,250))

# %%
## diameter
g = ig.Graph.Erdos_Renyi(n=50, m=100)
v = g.get_diameter()
g.vs['size']=10
g.vs['color']='lightblue'
g.es['color'] = 'grey'
for x in v:
    g.vs[x]['color'] = 'red'
for first, second in zip(v, v[1:]):
    g.es[g.get_eid(first, second)]['color'] = 'red'

ig.plot(g, layout="fr", vertex_label=None, bbox=(0,0,350,250))

# %% [markdown]
# ## Connected components

# %%
g = ig.Graph.Erdos_Renyi(n=100, m=100)
g.vs['size']=10
colors = ["lightgray", "cyan", "magenta", "yellow", "blue", "green", "red"]
for component in g.components():
  color = colors[min(6, len(component)-1)]
  for vidx in component: g.vs[vidx]["color"] = color
ig.plot(g, layout="fr", vertex_label=None, bbox=(0,0,350,250))

# %% [markdown]
# ## Large connected component

# %%
## avg degree k = p(n-1)
n = 1000
gcs = []
x = np.arange(.1,10.01,.1)
for k in x:
    p = k/(n-1)
    g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
    gcs.append(g.clusters().giant().vcount())

# %%
plt.plot(x,gcs)
plt.axvline(1,c='r')         ## critical point
plt.axvline(np.log(n),c='r') ## connected regime
plt.xlabel('average degree',fontsize=14)
plt.ylabel('giant component size',fontsize=14);

# %%
## looking at a smaller graph: subcritical regime
n = 50
k = .9 ## avg degree
p = k/(n-1)
g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
g.vs['color'] = 'blue'
g.vs['size'] = 10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
## looking at a smaller graph: supercritical regime
n = 50
k = np.log(n)-1 ## avg degree
p = k/(n-1)
g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
g.vs['color'] = 'blue'
g.vs['size'] = 10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
## looking at a smaller graph: connected regime
n = 50
k = np.log(n)+1
p = k/(n-1)
g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
g.vs['color'] = 'blue'
g.vs['size'] = 10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %% [markdown]
# ## Other characteristics

# %%
n = 500
k = np.log(n) ## avg degree
p = k/(n-1)
g = ig.Graph.Erdos_Renyi(n=n, p=p, directed=False, loops=False)
print('avg degree:',k)
# Out:
# avg degree: 6.214608098422191

# %%
## characteristic path length
print('avg path length:',g.average_path_length(),' approx:',np.log(n)/np.log(p*(n-1)))
# Out:
# avg path length: 3.6108441783164724  approx: 3.401718228036341

# %%
## assortativity close to 0
print('assortativity:',g.assortativity_degree())
# Out:
# assortativity: 0.02509760925507188

# %% [markdown]
# # Degree sequence models
#
# * Random graphs following some degree distribution
# * Configuration model considers a fixed sequence of degrees
# * Chung-Lu is a probabilistic model

# %%
## Configuration model - here with fixed degrees
d = [x+5 for x in np.random.choice(1,size=50)]
g = ig.Graph.Degree_Sequence(d)

# %%
g.vs['size']=10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\__init__.py in _repr_svg_(self)
#     365         context = cairo.Context(surface)
#     366         # Plot the graph on this context
# --> 367         self.redraw(context)
#     368         # No idea why this is needed but python crashes without
#     369         context.show_page()
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\__init__.py in redraw(self, context)
#     274                 else:
#     275                     ctx.save()
# --> 276                 plotter(ctx, bbox, palette, *args, **kwds)
#     277                 if opacity < 1.0:
#     278                     ctx.pop_group_to_source()
#
# E:\Anaconda3\lib\site-packages\igraph\__init__.py in __plot__(self, context, bbox, palette, *args, **kwds)
#    4164             del kwds["drawer_factory"]
#    4165         drawer = drawer_factory(context, bbox)
# -> 4166         drawer.draw(self, palette, *args, **kwds)
#    4167
#    4168     def __str__(self):
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\graph.py in draw(self, graph, palette, *args, **kwds)
#     358             src, dest = edge.tuple
#     359             src_vertex, dest_vertex = vertex_builder[src], vertex_builder[dest]
# --> 360             drawer_method(visual_edge, src_vertex, dest_vertex)
#     361
#     362         # Construct the iterator that we will use to draw the vertices
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\edge.py in draw_undirected_edge(self, edge, src_vertex, dest_vertex)
#     121             (x1, y1), (x2, y2) = src_vertex.position, dest_vertex.position
#     122
# --> 123             aux1, aux2 = get_bezier_control_points_for_curved_edge(x1, y1, x2, y2, edge['curved'])
#     124
#     125             ctx.curve_to(aux1[0], aux1[1], aux2[0], aux2[1], *dest_vertex.position)
#
# TypeError: 'VisualEdgeBuilder.Element' object is not subscriptable

# %%
## we can ignore multi-edges
g = ig.Graph.Degree_Sequence(d, method="no_multiple")
g.vs['size']=10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
## uniform degree distribution
s = 1
while s % 2 == 1:
    d = [x+2 for x in np.random.choice(5,size=50)]
    s = sum(d) ## should be even!
g = ig.Graph.Degree_Sequence(d)
print(g.degree_distribution())
# Out:
# N = 50, mean +- sd: 3.7600 +- 1.2216
# [2, 3): ******* (7)
# [3, 4): ***************** (17)
# [4, 5): ************* (13)
# [5, 6): ******* (7)
# [6, 7): ****** (6)

# %%
g.vs['size']=10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\__init__.py in _repr_svg_(self)
#     365         context = cairo.Context(surface)
#     366         # Plot the graph on this context
# --> 367         self.redraw(context)
#     368         # No idea why this is needed but python crashes without
#     369         context.show_page()
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\__init__.py in redraw(self, context)
#     274                 else:
#     275                     ctx.save()
# --> 276                 plotter(ctx, bbox, palette, *args, **kwds)
#     277                 if opacity < 1.0:
#     278                     ctx.pop_group_to_source()
#
# E:\Anaconda3\lib\site-packages\igraph\__init__.py in __plot__(self, context, bbox, palette, *args, **kwds)
#    4164             del kwds["drawer_factory"]
#    4165         drawer = drawer_factory(context, bbox)
# -> 4166         drawer.draw(self, palette, *args, **kwds)
#    4167
#    4168     def __str__(self):
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\graph.py in draw(self, graph, palette, *args, **kwds)
#     358             src, dest = edge.tuple
#     359             src_vertex, dest_vertex = vertex_builder[src], vertex_builder[dest]
# --> 360             drawer_method(visual_edge, src_vertex, dest_vertex)
#     361
#     362         # Construct the iterator that we will use to draw the vertices
#
# E:\Anaconda3\lib\site-packages\igraph\drawing\edge.py in draw_undirected_edge(self, edge, src_vertex, dest_vertex)
#     121             (x1, y1), (x2, y2) = src_vertex.position, dest_vertex.position
#     122
# --> 123             aux1, aux2 = get_bezier_control_points_for_curved_edge(x1, y1, x2, y2, edge['curved'])
#     124
#     125             ctx.curve_to(aux1[0], aux1[1], aux2[0], aux2[1], *dest_vertex.position)
#
# TypeError: 'VisualEdgeBuilder.Element' object is not subscriptable

# %%
g = ig.Graph.Degree_Sequence(d, method="no_multiple")
g.vs['size']=10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
print(g.degree_distribution())
# Out:
# N = 50, mean +- sd: 3.7600 +- 1.2216
# [2, 3): ******* (7)
# [3, 4): ***************** (17)
# [4, 5): ************* (13)
# [5, 6): ******* (7)
# [6, 7): ****** (6)

# %% [markdown]
# ## Chung-Lu model

# %%
def CL(d):
    m = np.sum(d)//2
    n = len(d)
    s = np.sum(d)
    p = [i/s for i in d]
    g = ig.Graph.Erdos_Renyi(n=n, m=0)
    while g.ecount() < m:
        e = np.random.choice(n, size=2, replace=False, p=p)
        g.add_edge(e[0],e[1])
    g.simplify()
    return g

# %%
## exp. degree 2-6
d = [x+2 for x in np.random.choice(5,size=50)]
g = CL(d)
g.vs['size']=10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
## exp. degree 5-9
d = [x+5 for x in np.random.choice(5,size=50)]
g = CL(d)
g.vs['size']=10
ly = g.layout("kk")  ## kamada-kawai; usually nice
ig.plot(g, layout=ly, bbox=(0,0,350,250))

# %%
print(g.degree_distribution())
# Out:
# N = 50, mean +- sd: 6.5200 +- 2.2879
# [ 2,  3): ** (2)
# [ 3,  4): *** (3)
# [ 4,  5): ** (2)
# [ 5,  6): ********* (9)
# [ 6,  7): *********** (11)
# [ 7,  8): ******* (7)
# [ 8,  9): ********** (10)
# [ 9, 10): * (1)
# [10, 11): * (1)
# [11, 12): ** (2)
# [12, 13): ** (2)

# %%
print('mean degree:',np.mean(d),' avg degree in g:',np.mean(g.degree()))
# Out:
# mean degree: 7.08  avg degree in g: 6.52
